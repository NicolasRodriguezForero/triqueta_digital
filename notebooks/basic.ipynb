# %%
import requests
from bs4 import BeautifulSoup
import re
from urllib.parse import urljoin
import json
import pandas as pd

# %%
BASE_URL = "https://www.idrd.gov.co"
START_URL = "https://www.idrd.gov.co/nuestros-programas"

headers = {
    "User-Agent": "Mozilla/5.0 (compatible; DataCollector/1.0; +https://yourdomain.example)"
}

resp = requests.get(START_URL, headers=headers, timeout=15)
resp.raise_for_status()
soup = BeautifulSoup(resp.text, "html.parser")

cards = []
# Buscar cualquier string que contenga "Escenario:" y tomar su contenedor más cercano
for marker in soup.find_all(string=re.compile(r'Escenario:', re.IGNORECASE)):
    # subir hasta un contenedor relevante (p.ej. el div padre con varias líneas)
    container = marker.find_parent()
    # intentar encontrar el contenedor que tiene todos los campos (subir más si es necesario)
    for _ in range(4):
        # heurística: si el contenedor contiene "Horario" y "Dirección", lo asumimos como tarjeta
        text = container.get_text(separator="\n", strip=True)
        if re.search(r'Horario[:\s]', text) and re.search(r'Direcci[oó]n[:\s]', text):
            break
        if container.parent:
            container = container.parent

    text = container.get_text(separator="\n", strip=True)
    # Extraer campos por líneas (hecha una extracción robusta por regex)
    datos = {}
    datos['raw_text'] = text

    # Title: primera línea antes de los asteriscos o separadores (heurística)
    lines = [l.strip() for l in text.splitlines() if l.strip()]
    # buscar título: normalmente la primera línea que no es "Escenario" ni "Horario"
    titulo = None
    for line in lines[:3]:
        if not re.search(r'Escenario:|Direcci[oó]n:|Horario:|D[ií]as:|Localidad:', line, re.IGNORECASE):
            titulo = line
            break
    datos['titulo'] = titulo or lines[0] if lines else None

    # Extraer campos con regex
    def extraer(pattern, text):
        m = re.search(pattern, text, re.IGNORECASE)
        return m.group(1).strip() if m else None

    datos['escenario'] = extraer(r'Escenario[:\s]*([^\n\r]+)', text)
    datos['direccion'] = extraer(r'Direcci[oó]n[:\s]*([^\n\r]+)', text)
    datos['horario'] = extraer(r'Horario[:\s]*([^\n\r]+)', text)
    datos['dias'] = extraer(r'D[ií]as[:\s]*([^\n\r]+)', text)
    datos['localidad'] = extraer(r'Localidad[:\s]*([^\n\r]+)', text)

    # enlace "Más información" relativo al container
    a_mas = container.find("a", string=re.compile(r'Más información', re.IGNORECASE))
    if a_mas and a_mas.get("href"):
        datos['mas_info_url'] = urljoin(BASE_URL, a_mas['href'])
    else:
        # buscar enlace cerca (en el siguiente sibling)
        a = container.find_next("a", string=re.compile(r'Más información', re.IGNORECASE))
        datos['mas_info_url'] = urljoin(BASE_URL, a['href']) if a and a.get("href") else None

    cards.append(datos)

# deduplicar por (titulo, escenario)
unique = {}
for c in cards:
    key = (c.get('titulo'), c.get('escenario'))
    unique[key] = c
result = list(unique.values())

print(json.dumps(result, ensure_ascii=False, indent=2))
# Out:
# [
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE ESTADIO OLAYA HERRERA\nDirección:\nCARRERA 21 NUMERO 25-35 SUR\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - VIERNES\nLocalidad:\nRafael Uribe Uribe\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE ESTADIO OLAYA HERRERA",
#     "direccion": "CARRERA 21 NUMERO 25-35 SUR",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - VIERNES",
#     "localidad": "Rafael Uribe Uribe",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nINTEGRACIÓN SOCIAL EL CAMINO( MANZANA ENGATIVÁ)\nDirección:\nCARRERA 69 47 43\nHorario:\n9:00:00 a. m.\nDías:\nLUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES\nLocalidad:\nEngativá\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "INTEGRACIÓN SOCIAL EL CAMINO( MANZANA ENGATIVÁ)",
#     "direccion": "CARRERA 69 47 43",
#     "horario": "9:00:00 a. m.",
#     "dias": "LUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES",
#     "localidad": "Engativá",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Caminatas\nEscenario:\nPlaza Cultural La Santamaría  (03-093)\nDirección:\nCarrera 6 #26-50\nHorario:\n06:00 p.m.  a 09:00 p.m.\nDías:\nViernes 24 de octubre\nLocalidad:\nSanta Fe\nFecha comienzo:\n24 de Octubre 2025\nFecha finalizacion:\n24 de Octubre 2025\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Caminatas",
#     "escenario": "Plaza Cultural La Santamaría  (03-093)",
#     "direccion": "Carrera 6 #26-50",
#     "horario": "06:00 p.m.  a 09:00 p.m.",
#     "dias": "Viernes 24 de octubre",
#     "localidad": "Santa Fe",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE DESARROLLO SANTA BARBARA\nDirección:\nCALLE 59 SUR # 115A - 113\nHorario:\n8:30:00 a. m.\nDías:\nMARTES\nLocalidad:\nBosa\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE DESARROLLO SANTA BARBARA",
#     "direccion": "CALLE 59 SUR # 115A - 113",
#     "horario": "8:30:00 a. m.",
#     "dias": "MARTES",
#     "localidad": "Bosa",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE TIERRA LINDA\nDirección:\nCLL 127 C # 49 78\nHorario:\n7:30:00 a. m.\nDías:\nMIÉRCOLES\nLocalidad:\nSuba\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE TIERRA LINDA",
#     "direccion": "CLL 127 C # 49 78",
#     "horario": "7:30:00 a. m.",
#     "dias": "MIÉRCOLES",
#     "localidad": "Suba",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nHOGAR BETANIA (MANZANA SAN CRISTOBAL)\nDirección:\nCALLE 11 SUR # 7A 29\nHorario:\n9:30:00 a. m.\nDías:\nVIERNES\nLocalidad:\nSan Cristóbal\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "HOGAR BETANIA (MANZANA SAN CRISTOBAL)",
#     "direccion": "CALLE 11 SUR # 7A 29",
#     "horario": "9:30:00 a. m.",
#     "dias": "VIERNES",
#     "localidad": "San Cristóbal",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE URBANIZACIÓN SANTIAGO DE ATALAYAS\nDirección:\nCARRERA 93D # 59B\nHorario:\n9:00:00 a. m.\nDías:\nMIÉRCOLES\nLocalidad:\nBosa\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE URBANIZACIÓN SANTIAGO DE ATALAYAS",
#     "direccion": "CARRERA 93D # 59B",
#     "horario": "9:00:00 a. m.",
#     "dias": "MIÉRCOLES",
#     "localidad": "Bosa",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCADE GAITANA\nDirección:\nTRANS 126 # 134 - 88\nHorario:\n7:30:00 a. m.\nDías:\nMARTES - MIÉRCOLES\nLocalidad:\nSuba\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CADE GAITANA",
#     "direccion": "TRANS 126 # 134 - 88",
#     "horario": "7:30:00 a. m.",
#     "dias": "MARTES - MIÉRCOLES",
#     "localidad": "Suba",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE SANTA ROSITA\nDirección:\nEntre Carrera 92 Y Carrera 93 A Con Calle 76 Bis\nHorario:\n7:00:00 a. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nEngativá\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE SANTA ROSITA",
#     "direccion": "Entre Carrera 92 Y Carrera 93 A Con Calle 76 Bis",
#     "horario": "7:00:00 a. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Engativá",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE ALOHA MARSELLA\nDirección:\nCALLE 7 A BIS # 71A - 20\nHorario:\n7:30:00 a. m.\nDías:\nLUNES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE ALOHA MARSELLA",
#     "direccion": "CALLE 7 A BIS # 71A - 20",
#     "horario": "7:30:00 a. m.",
#     "dias": "LUNES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nURBANIZACIÓN QUIRIGUA\nDirección:\nCARRERA  90 # 84 A 38\nHorario:\n7:00:00 a. m.\nDías:\nVIERNES\nLocalidad:\nEngativá\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "URBANIZACIÓN QUIRIGUA",
#     "direccion": "CARRERA  90 # 84 A 38",
#     "horario": "7:00:00 a. m.",
#     "dias": "VIERNES",
#     "localidad": "Engativá",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE HUMBERTO VALENCIA\nDirección:\nCL. 71A SUR #81 44\nHorario:\n8:00:00 a. m.\nDías:\nMARTES\nLocalidad:\nBosa\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE HUMBERTO VALENCIA",
#     "direccion": "CL. 71A SUR #81 44",
#     "horario": "8:00:00 a. m.",
#     "dias": "MARTES",
#     "localidad": "Bosa",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nBIBLIOTECA CARLOS E. RESTREPO (MANZANA DE ANTONIO NARIÑO)\nDirección:\nTRANSVERSAL 21 A #19 - 54 SUR\nHorario:\n8:00:00 a. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nAntonio Nariño\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "BIBLIOTECA CARLOS E. RESTREPO (MANZANA DE ANTONIO NARIÑO)",
#     "direccion": "TRANSVERSAL 21 A #19 - 54 SUR",
#     "horario": "8:00:00 a. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Antonio Nariño",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nDESARROLLO ALFONSO LÓPEZ  SECTOR NUEVO PROGRESO\nDirección:\nCALLE 93 SUR # 6B -12 ESTE\nHorario:\n8:00:00 a. m.\nDías:\nMARTES - MIÉRCOLES - JUEVES\nLocalidad:\nUsme\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "DESARROLLO ALFONSO LÓPEZ  SECTOR NUEVO PROGRESO",
#     "direccion": "CALLE 93 SUR # 6B -12 ESTE",
#     "horario": "8:00:00 a. m.",
#     "dias": "MARTES - MIÉRCOLES - JUEVES",
#     "localidad": "Usme",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE ALAMEDA\nDirección:\nCRA. 80I #73C SUR-2 A 73C SUR-52\nHorario:\n8:00:00 a. m.\nDías:\nLUNES\nLocalidad:\nBosa\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE ALAMEDA",
#     "direccion": "CRA. 80I #73C SUR-2 A 73C SUR-52",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES",
#     "localidad": "Bosa",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE COLISEO EL JAZMÍN\nDirección:\nAVENIDA CARRERA 50 N 1 D 28\nHorario:\n2:00:00 p. m.\nDías:\nVIERNES\nLocalidad:\nPuente Aranda\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE COLISEO EL JAZMÍN",
#     "direccion": "AVENIDA CARRERA 50 N 1 D 28",
#     "horario": "2:00:00 p. m.",
#     "dias": "VIERNES",
#     "localidad": "Puente Aranda",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nALFONSO LÓPEZ MICHELSEN\nDirección:\nCALLE 53 BIS # 80 A 35\nHorario:\n5:00:00 p. m.\nDías:\nMIÉRCOLES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "ALFONSO LÓPEZ MICHELSEN",
#     "direccion": "CALLE 53 BIS # 80 A 35",
#     "horario": "5:00:00 p. m.",
#     "dias": "MIÉRCOLES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE URBANIZACIÓN BRASILIA\nDirección:\nCARRERA 1 BIS A ESTE (CALLE 88B SUR) CON CALLE 73\nHorario:\n7:00:00 a. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nUsme\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE URBANIZACIÓN BRASILIA",
#     "direccion": "CARRERA 1 BIS A ESTE (CALLE 88B SUR) CON CALLE 73",
#     "horario": "7:00:00 a. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Usme",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE VILLA DIANA\nDirección:\nCARRERA 17B #13-16\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - VIERNES\nLocalidad:\nCiudad Bolívar\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE VILLA DIANA",
#     "direccion": "CARRERA 17B #13-16",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - VIERNES",
#     "localidad": "Ciudad Bolívar",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCASA DE LA SABIDURÍA  (MANZANA CHAPINERO )\nDirección:\nCALLE 71 # 10-47\nHorario:\n10:00:00 a. m.\nDías:\nVIERNES\nLocalidad:\nChapinero\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CASA DE LA SABIDURÍA  (MANZANA CHAPINERO )",
#     "direccion": "CALLE 71 # 10-47",
#     "horario": "10:00:00 a. m.",
#     "dias": "VIERNES",
#     "localidad": "Chapinero",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCANDELARIA SALÓN COMUNAL (MANZANA SIERRA MORENA)\nDirección:\nCALLE 1A 68C, C 68C SUR\nHorario:\n10:00:00 a. m.\nDías:\nMARTES\nLocalidad:\nCiudad Bolívar\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CANDELARIA SALÓN COMUNAL (MANZANA SIERRA MORENA)",
#     "direccion": "CALLE 1A 68C, C 68C SUR",
#     "horario": "10:00:00 a. m.",
#     "dias": "MARTES",
#     "localidad": "Ciudad Bolívar",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE CIUDAD BERNA\nDirección:\nCARRERA 12 # 7-44 sur\nHorario:\n2:00:00 p. m.\nDías:\nVIERNES\nLocalidad:\nAntonio Nariño\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE CIUDAD BERNA",
#     "direccion": "CARRERA 12 # 7-44 sur",
#     "horario": "2:00:00 p. m.",
#     "dias": "VIERNES",
#     "localidad": "Antonio Nariño",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE METRÓPOLIS\nDirección:\nCALLE 78 CR 66\nHorario:\n8:00:00 a. m.\nDías:\nMARTES - MIÉRCOLES - JUEVES - VIERNES\nLocalidad:\nAntonio Nariño\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE METRÓPOLIS",
#     "direccion": "CALLE 78 CR 66",
#     "horario": "8:00:00 a. m.",
#     "dias": "MARTES - MIÉRCOLES - JUEVES - VIERNES",
#     "localidad": "Antonio Nariño",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE BATAVIA\nDirección:\nCARRERA 104B#22J-15\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - MIÉRCOLES\nLocalidad:\nFontibón\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE BATAVIA",
#     "direccion": "CARRERA 104B#22J-15",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - MIÉRCOLES",
#     "localidad": "Fontibón",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nPARQUE CUADRADO\nDirección:\nCALLE 65 # 56-72\nHorario:\n5:00:00 p. m.\nDías:\nLUNES - MIÉRCOLES\nLocalidad:\nAntonio Nariño\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "PARQUE CUADRADO",
#     "direccion": "CALLE 65 # 56-72",
#     "horario": "5:00:00 p. m.",
#     "dias": "LUNES - MIÉRCOLES",
#     "localidad": "Antonio Nariño",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE LA UNIDAD\nDirección:\nCALLE 57 D SUR N° 77 I - 12\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - VIERNES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE LA UNIDAD",
#     "direccion": "CALLE 57 D SUR N° 77 I - 12",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - VIERNES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nPARQUE RENACIMIENTO (MANZANA DE LOS MÁRTIRES)\nDirección:\nAVENIDA CALLE 26 # 19 B - 55\nHorario:\n7:00:00 a. m.\nDías:\nLUNES- MIÉRCOLES - VIERNES\nLocalidad:\nLos Mártires\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "PARQUE RENACIMIENTO (MANZANA DE LOS MÁRTIRES)",
#     "direccion": "AVENIDA CALLE 26 # 19 B - 55",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES- MIÉRCOLES - VIERNES",
#     "localidad": "Los Mártires",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nPARQUE EL BRASIL\nDirección:\nCALLE 39 # 17-48\nHorario:\n2:00:00 p. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nTeusaquillo\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "PARQUE EL BRASIL",
#     "direccion": "CALLE 39 # 17-48",
#     "horario": "2:00:00 p. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Teusaquillo",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nCENTRO DIA QUIROGA\nDirección:\nCARRERA 24 #33-07 sur\nHorario:\n9:00:00 a. m.\nDías:\nLUNES - MARTES - JUEVES\nLocalidad:\nRafael Uribe Uribe\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "CENTRO DIA QUIROGA",
#     "direccion": "CARRERA 24 #33-07 sur",
#     "horario": "9:00:00 a. m.",
#     "dias": "LUNES - MARTES - JUEVES",
#     "localidad": "Rafael Uribe Uribe",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE FERRO CAJAS\nDirección:\nAVENIDA CARRERA 86  # 23 C 00\nHorario:\n8:00:00 a. m.\nDías:\nMIÉRCOLES - VIERNES\nLocalidad:\nFontibón\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE FERRO CAJAS",
#     "direccion": "AVENIDA CARRERA 86  # 23 C 00",
#     "horario": "8:00:00 a. m.",
#     "dias": "MIÉRCOLES - VIERNES",
#     "localidad": "Fontibón",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE DESARROLLO LA CONCEPCIÓN\nDirección:\nENTRE CARRERA 100C (105B) Y TRANSVERSAL 100D\nHorario:\n7:00:00 a. m.\nDías:\nJUEVES - VIERNES\nLocalidad:\nBosa\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE DESARROLLO LA CONCEPCIÓN",
#     "direccion": "ENTRE CARRERA 100C (105B) Y TRANSVERSAL 100D",
#     "horario": "7:00:00 a. m.",
#     "dias": "JUEVES - VIERNES",
#     "localidad": "Bosa",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nPARQUE VELÓDROMO ( MANZANAS DEL CUIDADO CEFE SAN CRISTOBAL)\nDirección:\nZONA UBICADA EN LA PROLONGACIÓN DE LA CALLE 14 SUR ENTRE CARRERA 4 Y CARRERA 6\nHorario:\n8:00:00 a. m.\nDías:\nMIÉRCOLES - VIERNES\nLocalidad:\nSan Cristóbal\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "PARQUE VELÓDROMO ( MANZANAS DEL CUIDADO CEFE SAN CRISTOBAL)",
#     "direccion": "ZONA UBICADA EN LA PROLONGACIÓN DE LA CALLE 14 SUR ENTRE CARRERA 4 Y CARRERA 6",
#     "horario": "8:00:00 a. m.",
#     "dias": "MIÉRCOLES - VIERNES",
#     "localidad": "San Cristóbal",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nSALÓN COMUNAL ALCAPARRO (MANZANA CAMPO VERDE)\nDirección:\nCALLE 80 BIS SUR, 94-21\nHorario:\n5:00:00 p. m.\nDías:\nLUNES\nLocalidad:\nBosa\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "SALÓN COMUNAL ALCAPARRO (MANZANA CAMPO VERDE)",
#     "direccion": "CALLE 80 BIS SUR, 94-21",
#     "horario": "5:00:00 p. m.",
#     "dias": "LUNES",
#     "localidad": "Bosa",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nNUEVO AMANECER SAN TITO DE ONASSIS\nDirección:\nTRANSVERSAL 78H # 43 A 02 sur\nHorario:\n7:30:00 a. m.\nDías:\nVIERNES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "NUEVO AMANECER SAN TITO DE ONASSIS",
#     "direccion": "TRANSVERSAL 78H # 43 A 02 sur",
#     "horario": "7:30:00 a. m.",
#     "dias": "VIERNES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nCANCHA FONTANAR\nDirección:\nTV 142 # 150 A 40\nHorario:\n8:00:00 a. m.\nDías:\nLUNES - MARTES\nLocalidad:\nSuba\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "CANCHA FONTANAR",
#     "direccion": "TV 142 # 150 A 40",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES - MARTES",
#     "localidad": "Suba",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nSALÓN COMUNAL  CARIMAGUA (MANZANA TIMIZA)\nDirección:\nCALLE 56 sur # 81- 47\nHorario:\n10:00:00 a. m.\nDías:\nMIÉRCOLES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "SALÓN COMUNAL  CARIMAGUA (MANZANA TIMIZA)",
#     "direccion": "CALLE 56 sur # 81- 47",
#     "horario": "10:00:00 a. m.",
#     "dias": "MIÉRCOLES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nPARQUE TUNDAMA\nDirección:\nCALLE 47 SUR  N° 72 I -06\nHorario:\n8:30:00 a. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "PARQUE TUNDAMA",
#     "direccion": "CALLE 47 SUR  N° 72 I -06",
#     "horario": "8:30:00 a. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE VILLA DEL CERRO\nDirección:\nCALLE 46 BIS SUR CON DIAGONAL 45 BIS CALLE 46A SUR  COSTADO NORTE\nHorario:\n6:30:00 a. m.\nDías:\nJUEVES\nLocalidad:\nSan Cristóbal\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE VILLA DEL CERRO",
#     "direccion": "CALLE 46 BIS SUR CON DIAGONAL 45 BIS CALLE 46A SUR  COSTADO NORTE",
#     "horario": "6:30:00 a. m.",
#     "dias": "JUEVES",
#     "localidad": "San Cristóbal",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE ATALAYAS II SECTOR\nDirección:\nCARRERA 99A CON CALLE 54 SUR\nHorario:\n7:00:00 a. m.\nDías:\nMIÉRCOLES - VIERNES\nLocalidad:\nBosa\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE ATALAYAS II SECTOR",
#     "direccion": "CARRERA 99A CON CALLE 54 SUR",
#     "horario": "7:00:00 a. m.",
#     "dias": "MIÉRCOLES - VIERNES",
#     "localidad": "Bosa",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE VALPARAÍSO\nDirección:\nCALLE 66 SUR# 11A 62  ESTE\nHorario:\n2:00:00 p. m.\nDías:\nLUNES - JUEVES\nLocalidad:\nSan Cristóbal\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE VALPARAÍSO",
#     "direccion": "CALLE 66 SUR# 11A 62  ESTE",
#     "horario": "2:00:00 p. m.",
#     "dias": "LUNES - JUEVES",
#     "localidad": "San Cristóbal",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCIOM CANDELARIA (MANZANA CENTRO)\nDirección:\nCALLE 9 # 3 -11\nHorario:\n2:00:00 p. m.\nDías:\nMIÉRCOLES\nLocalidad:\nLa Candelaria\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CIOM CANDELARIA (MANZANA CENTRO)",
#     "direccion": "CALLE 9 # 3 -11",
#     "horario": "2:00:00 p. m.",
#     "dias": "MIÉRCOLES",
#     "localidad": "La Candelaria",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE SAN FELIPE\nDirección:\nCl. 75 #22-58\nHorario:\n8:00:00 a. m.\nDías:\nLUNES\nLocalidad:\nAntonio Nariño\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE SAN FELIPE",
#     "direccion": "Cl. 75 #22-58",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES",
#     "localidad": "Antonio Nariño",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nSANTA CATALINA\nDirección:\nCARRERA 81 F # 11B 10\nHorario:\n8:00:00 a. m.\nDías:\nLUNES - MIÉRCOLES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "SANTA CATALINA",
#     "direccion": "CARRERA 81 F # 11B 10",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES - MIÉRCOLES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE GUSTAVO URIBE\nDirección:\nCR 1 70 11\nHorario:\n7:30:00 a. m.\nDías:\nLUNES-MIÉRCOLES - VIERNES\nLocalidad:\nChapinero\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE GUSTAVO URIBE",
#     "direccion": "CR 1 70 11",
#     "horario": "7:30:00 a. m.",
#     "dias": "LUNES-MIÉRCOLES - VIERNES",
#     "localidad": "Chapinero",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nSALÓN COMUNAL ABRAHÁN LINCOLN(MANZANAS DEL CUIDADO)\nDirección:\nCL 53 SUR CRA 11 A\nHorario:\n7:30:00 a. m.\nDías:\nLUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES\nLocalidad:\nTunjuelito\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "SALÓN COMUNAL ABRAHÁN LINCOLN(MANZANAS DEL CUIDADO)",
#     "direccion": "CL 53 SUR CRA 11 A",
#     "horario": "7:30:00 a. m.",
#     "dias": "LUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES",
#     "localidad": "Tunjuelito",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE BERLÍN\nDirección:\nCALLE 146 C BIS # 90 - 57\nHorario:\n8:00:00 a. m.\nDías:\nMIÉRCOLES\nLocalidad:\nSuba\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE BERLÍN",
#     "direccion": "CALLE 146 C BIS # 90 - 57",
#     "horario": "8:00:00 a. m.",
#     "dias": "MIÉRCOLES",
#     "localidad": "Suba",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE URB. LAS MARGARITAS  (PARQUE MUNDO)\nDirección:\nDIAGONAL 49 SUR CON CARRERA 87\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - JUEVES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE URB. LAS MARGARITAS  (PARQUE MUNDO)",
#     "direccion": "DIAGONAL 49 SUR CON CARRERA 87",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - JUEVES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nAgrupación VIVIENDA GRANADA NORTE\nDirección:\nCALLE 167 # 51 - 40\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - VIERNES\nLocalidad:\nSuba\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "Agrupación VIVIENDA GRANADA NORTE",
#     "direccion": "CALLE 167 # 51 - 40",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - VIERNES",
#     "localidad": "Suba",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Caminatas\nEscenario:\nParque Nacional Enrique Olaya Herrera – Tanques del Silencio\nDirección:\nCalle 35 #3-50 (frente a la torre del reloj suizo).\nHorario:\n08:00 a.m.  a 11:00 a.m.\nDías:\nDomingo 19 de octubre\nLocalidad:\nSanta Fe\nFecha comienzo:\n19 de Octubre 2025\nFecha finalizacion:\n19 de Octubre 2025\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Caminatas",
#     "escenario": "Parque Nacional Enrique Olaya Herrera – Tanques del Silencio",
#     "direccion": "Calle 35 #3-50 (frente a la torre del reloj suizo).",
#     "horario": "08:00 a.m.  a 11:00 a.m.",
#     "dias": "Domingo 19 de octubre",
#     "localidad": "Santa Fe",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nPARQUE PALESTINA\nDirección:\nCALLE 68 SUR NUMERO 81 C 12\nHorario:\n8:00:00 a. m.\nDías:\nMIÉRCOLES\nLocalidad:\nBosa\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "PARQUE PALESTINA",
#     "direccion": "CALLE 68 SUR NUMERO 81 C 12",
#     "horario": "8:00:00 a. m.",
#     "dias": "MIÉRCOLES",
#     "localidad": "Bosa",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nALFONSO LÓPEZ MICHELSEN\nDirección:\nCALLE 53 BIS # 80 A 35\nHorario:\n6:00:00 p. m.\nDías:\nVIERNES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "ALFONSO LÓPEZ MICHELSEN",
#     "direccion": "CALLE 53 BIS # 80 A 35",
#     "horario": "6:00:00 p. m.",
#     "dias": "VIERNES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE PATIO BONITO 2 SECTOR\nDirección:\nCALLE 2 #87-15\nHorario:\n7:00:00 a. m.\nDías:\nMARTES - VIERNES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE PATIO BONITO 2 SECTOR",
#     "direccion": "CALLE 2 #87-15",
#     "horario": "7:00:00 a. m.",
#     "dias": "MARTES - VIERNES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nCANCHA COMUNAL MARANDU\nDirección:\nCALLE 68D SUR #18- 38\nHorario:\n8:00:00 a. m.\nDías:\nLUNES - MIÉRCOLES\nLocalidad:\nCiudad Bolívar\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "CANCHA COMUNAL MARANDU",
#     "direccion": "CALLE 68D SUR #18- 38",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES - MIÉRCOLES",
#     "localidad": "Ciudad Bolívar",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nAULA AMBIENTAL JUAN REY (MANZANA JUAN REY)\nDirección:\nCALLE 72A BIS SUR #13-21 ESTE\nHorario:\n2:00:00 p. m.\nDías:\nLUNES - MARTES - MIÉRCOLES\nLocalidad:\nSan Cristóbal\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "AULA AMBIENTAL JUAN REY (MANZANA JUAN REY)",
#     "direccion": "CALLE 72A BIS SUR #13-21 ESTE",
#     "horario": "2:00:00 p. m.",
#     "dias": "LUNES - MARTES - MIÉRCOLES",
#     "localidad": "San Cristóbal",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nCENTRO PASTORAL SAN JUAN DE DIOS (5095)\nDirección:\nCARRERA 1A # 1 - 41\nHorario:\n2:00:00 p. m.\nDías:\nSÁBADO\nLocalidad:\nSanta Fe\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "CENTRO PASTORAL SAN JUAN DE DIOS (5095)",
#     "direccion": "CARRERA 1A # 1 - 41",
#     "horario": "2:00:00 p. m.",
#     "dias": "SÁBADO",
#     "localidad": "Santa Fe",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE LOS CIPRÉS\nDirección:\nCRA.50 # 22-41\nHorario:\n8:00:00 a. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nTeusaquillo\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE LOS CIPRÉS",
#     "direccion": "CRA.50 # 22-41",
#     "horario": "8:00:00 a. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Teusaquillo",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE SAN LUIS\nDirección:\nCALLE 60 # 18-41\nHorario:\n8:00:00 a. m.\nDías:\nLUNES - MIÉRCOLES\nLocalidad:\nAntonio Nariño\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE SAN LUIS",
#     "direccion": "CALLE 60 # 18-41",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES - MIÉRCOLES",
#     "localidad": "Antonio Nariño",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE LOS SAUCES\nDirección:\nCALLE 29 SUR # 37 - 21\nHorario:\n2:00:00 p. m.\nDías:\nVIERNES\nLocalidad:\nPuente Aranda\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE LOS SAUCES",
#     "direccion": "CALLE 29 SUR # 37 - 21",
#     "horario": "2:00:00 p. m.",
#     "dias": "VIERNES",
#     "localidad": "Puente Aranda",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nPARQUE CONDOMINIOS\nDirección:\nCALLE 34 BIS SUR # 75 A 34\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - JUEVES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "PARQUE CONDOMINIOS",
#     "direccion": "CALLE 34 BIS SUR # 75 A 34",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - JUEVES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPALERMO SUR\nDirección:\nDIAGONAL 49 BIS SUR CARRERA  2a Y 4\nHorario:\n8:00:00 a. m.\nDías:\nLUNES - JUEVES\nLocalidad:\nRafael Uribe Uribe\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PALERMO SUR",
#     "direccion": "DIAGONAL 49 BIS SUR CARRERA  2a Y 4",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES - JUEVES",
#     "localidad": "Rafael Uribe Uribe",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE SONORA\nDirección:\nCALLE 152 CON  CARRERA 7C\nHorario:\n8:30:00 a. m.\nDías:\nJUEVES\nLocalidad:\nUsaquén\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE SONORA",
#     "direccion": "CALLE 152 CON  CARRERA 7C",
#     "horario": "8:30:00 a. m.",
#     "dias": "JUEVES",
#     "localidad": "Usaquén",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE CHAMPIONS\nDirección:\nCARRERA 43 #5, Bogotá\nHorario:\n8:00:00 a. m.\nDías:\nLUNES - MARTES - JUEVES\nLocalidad:\nPuente Aranda\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE CHAMPIONS",
#     "direccion": "CARRERA 43 #5, Bogotá",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES - MARTES - JUEVES",
#     "localidad": "Puente Aranda",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nCENTRO DIA MONSEÑOR - SANTA MATILDE\nDirección:\nCALLE 27 B SUR # 37 - 07\nHorario:\n8:00:00 a. m.\nDías:\nLUNES\nLocalidad:\nPuente Aranda\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "CENTRO DIA MONSEÑOR - SANTA MATILDE",
#     "direccion": "CALLE 27 B SUR # 37 - 07",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES",
#     "localidad": "Puente Aranda",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCASA DE LA JUVENTUD (MANZANA DE ANTONIO NARIÑO)\nDirección:\nCARRERA 20 # 19 SUR-26\nHorario:\n9:00:00 a. m.\nDías:\nVIERNES\nLocalidad:\nAntonio Nariño\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CASA DE LA JUVENTUD (MANZANA DE ANTONIO NARIÑO)",
#     "direccion": "CARRERA 20 # 19 SUR-26",
#     "horario": "9:00:00 a. m.",
#     "dias": "VIERNES",
#     "localidad": "Antonio Nariño",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCENTRO DIA USAQUEN CASA DEL ÁRBOL  (MANZANA USAQUÉN)\nDirección:\nCARRERA 7A # 182-35\nHorario:\n2:00:00 p. m.\nDías:\nLUNES - VIERNES\nLocalidad:\nUsaquén\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CENTRO DIA USAQUEN CASA DEL ÁRBOL  (MANZANA USAQUÉN)",
#     "direccion": "CARRERA 7A # 182-35",
#     "horario": "2:00:00 p. m.",
#     "dias": "LUNES - VIERNES",
#     "localidad": "Usaquén",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE BOSQUE DE HAYUELOS\nDirección:\nCARRERA 81 B # 19 - 00\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - MARTES - VIERNES\nLocalidad:\nFontibón\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE BOSQUE DE HAYUELOS",
#     "direccion": "CARRERA 81 B # 19 - 00",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - MARTES - VIERNES",
#     "localidad": "Fontibón",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nBUENAVISTA SEGUNDO SECTOR\nDirección:\nCL 189 C 3 A 01\nHorario:\n7:00:00 a. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nUsaquén\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "BUENAVISTA SEGUNDO SECTOR",
#     "direccion": "CL 189 C 3 A 01",
#     "horario": "7:00:00 a. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Usaquén",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCOOPERATIVA ISMAEL PERDOMO MANZANAS\nDirección:\nCALLE 63 SUR A # 73 D\nHorario:\n7:00:00 a. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nCiudad Bolívar\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "COOPERATIVA ISMAEL PERDOMO MANZANAS",
#     "direccion": "CALLE 63 SUR A # 73 D",
#     "horario": "7:00:00 a. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Ciudad Bolívar",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nURBANIZACIÓN CERROS DE ORIENTE\nDirección:\nCARRERA 3 Y TRANS 4 CON CALLE 48H SUR\nHorario:\n7:00:00 a. m.\nDías:\nMIÉRCOLES\nLocalidad:\nRafael Uribe Uribe\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "URBANIZACIÓN CERROS DE ORIENTE",
#     "direccion": "CARRERA 3 Y TRANS 4 CON CALLE 48H SUR",
#     "horario": "7:00:00 a. m.",
#     "dias": "MIÉRCOLES",
#     "localidad": "Rafael Uribe Uribe",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nPARQUE ZONAL CAMPO VERDE (MANZANA CAMPO VERDE)\nDirección:\nCALLE 85 SUR #92-85\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - MARTES  - MIÉRCOLES - JUEVES - VIERNES\nLocalidad:\nBosa\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "PARQUE ZONAL CAMPO VERDE (MANZANA CAMPO VERDE)",
#     "direccion": "CALLE 85 SUR #92-85",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - MARTES  - MIÉRCOLES - JUEVES - VIERNES",
#     "localidad": "Bosa",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE LA EUROPA\nDirección:\nCARRERA 71 B Calle 68 B\nHorario:\n2:00:00 p. m.\nDías:\nMIÉRCOLES - VIERNES\nLocalidad:\nEngativá\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE LA EUROPA",
#     "direccion": "CARRERA 71 B Calle 68 B",
#     "horario": "2:00:00 p. m.",
#     "dias": "MIÉRCOLES - VIERNES",
#     "localidad": "Engativá",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE CARBONEL\nDirección:\nTRANSVERSAL 77I BIS #71C SUR-20  CALLE 71C SUR #C2\nHorario:\n8:00:00 a. m.\nDías:\nMIÉRCOLES - VIERNES\nLocalidad:\nBosa\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE CARBONEL",
#     "direccion": "TRANSVERSAL 77I BIS #71C SUR-20  CALLE 71C SUR #C2",
#     "horario": "8:00:00 a. m.",
#     "dias": "MIÉRCOLES - VIERNES",
#     "localidad": "Bosa",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nCANCHA COMUNAL ACACIAS\nDirección:\nCRA 19B N 62B 05\nHorario:\n8:00:00 a. m.\nDías:\nMARTES - JUEVES - VIERNES\nLocalidad:\nCiudad Bolívar\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "CANCHA COMUNAL ACACIAS",
#     "direccion": "CRA 19B N 62B 05",
#     "horario": "8:00:00 a. m.",
#     "dias": "MARTES - JUEVES - VIERNES",
#     "localidad": "Ciudad Bolívar",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCANDELARIA SALÓN COMUNAL\nDirección:\nCALLE 1 A 68 C SUR\nHorario:\n10:00:00 a. m.\nDías:\nJUEVES\nLocalidad:\nCiudad Bolívar\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CANDELARIA SALÓN COMUNAL",
#     "direccion": "CALLE 1 A 68 C SUR",
#     "horario": "10:00:00 a. m.",
#     "dias": "JUEVES",
#     "localidad": "Ciudad Bolívar",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nPARQUE TIERRA BUENA\nDirección:\nCALLE 34 BIS SUR N°  95a-56\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - MARTES - MIÉRCOLES-VIERNES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "PARQUE TIERRA BUENA",
#     "direccion": "CALLE 34 BIS SUR N°  95a-56",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - MARTES - MIÉRCOLES-VIERNES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE URB. NUEVA TIBABUYES (PILOTO)\nDirección:\nCRA 113 C #142 A 53\nHorario:\n7:00:00 a. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nSuba\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE URB. NUEVA TIBABUYES (PILOTO)",
#     "direccion": "CRA 113 C #142 A 53",
#     "horario": "7:00:00 a. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Suba",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCDC LAGO TIMIZA (MANZANA TIMIZA)\nDirección:\nCARRERA 74 # 42 G - 52 SUR\nHorario:\n2:00:00 p. m.\nDías:\nLUNES - MIÉRCOLES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CDC LAGO TIMIZA (MANZANA TIMIZA)",
#     "direccion": "CARRERA 74 # 42 G - 52 SUR",
#     "horario": "2:00:00 p. m.",
#     "dias": "LUNES - MIÉRCOLES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nURBANIZACIÓN BONANZA PRIMER SECTOR\nDirección:\nCARRERA 70 f # 73a 62\nHorario:\n8:00:00 a. m.\nDías:\nLUNES - JUEVES\nLocalidad:\nEngativá\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "URBANIZACIÓN BONANZA PRIMER SECTOR",
#     "direccion": "CARRERA 70 f # 73a 62",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES - JUEVES",
#     "localidad": "Engativá",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE LA MANUELITA\nDirección:\nCRA 89 B #124 A\nHorario:\n8:00:00 a. m.\nDías:\nLUNES\nLocalidad:\nSuba\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE LA MANUELITA",
#     "direccion": "CRA 89 B #124 A",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES",
#     "localidad": "Suba",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCASA DE LA PARTICIPACIÓN\nDirección:\nCALLE 39B # 19-46\nHorario:\n2:00:00 p. m.\nDías:\nLUNES - VIERNES\nLocalidad:\nTeusaquillo\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CASA DE LA PARTICIPACIÓN",
#     "direccion": "CALLE 39B # 19-46",
#     "horario": "2:00:00 p. m.",
#     "dias": "LUNES - VIERNES",
#     "localidad": "Teusaquillo",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCENTRO DE DESARROLLO COMUNITARIO  JULIO CESAR SÁNCHEZ(MANZANAS DEL CUIDADO USME)\nDirección:\nCALLE 91 A SUR 3 C - 34\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - VIERNES\nLocalidad:\nUsme\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CENTRO DE DESARROLLO COMUNITARIO  JULIO CESAR SÁNCHEZ(MANZANAS DEL CUIDADO USME)",
#     "direccion": "CALLE 91 A SUR 3 C - 34",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - VIERNES",
#     "localidad": "Usme",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nDESARROLLO UNICERROS\nDirección:\nCARRERA 1 B BIS CON CALLE 128 C COSTADO NORTE\nHorario:\n7:00:00 a. m.\nDías:\nJUEVES\nLocalidad:\nUsaquén\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "DESARROLLO UNICERROS",
#     "direccion": "CARRERA 1 B BIS CON CALLE 128 C COSTADO NORTE",
#     "horario": "7:00:00 a. m.",
#     "dias": "JUEVES",
#     "localidad": "Usaquén",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE CHUNIZA\nDirección:\nCARRERA 3C 56 ESTE CON CALLE 87 SUR COSTADO NOROCCIDENTAL\nHorario:\n8:00:00 a. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nUsme\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE CHUNIZA",
#     "direccion": "CARRERA 3C 56 ESTE CON CALLE 87 SUR COSTADO NOROCCIDENTAL",
#     "horario": "8:00:00 a. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Usme",
# ...
#     "direccion": "CARRERA 57 # 56 - 36",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES",
#     "localidad": "Teusaquillo",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCEFE SAN CRISTOBAL (MANZANA CEFE SAN CRISTOBAL)\nDirección:\nCALLE 17A SUR 2A -60 ESTE\nHorario:\n2:00:00 p. m.\nDías:\nLUNES - MIÉRCOLES - VIERNES\nLocalidad:\nSan Cristóbal\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CEFE SAN CRISTOBAL (MANZANA CEFE SAN CRISTOBAL)",
#     "direccion": "CALLE 17A SUR 2A -60 ESTE",
#     "horario": "2:00:00 p. m.",
#     "dias": "LUNES - MIÉRCOLES - VIERNES",
#     "localidad": "San Cristóbal",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE CODABAS\nDirección:\nCALLE 181A ENTRE CARRERA 7C Y 8 COSTADO SUR-. ORIENTAL.\nHorario:\n7:00:00 a. m.\nDías:\nMIÉRCOLES - VIERNES\nLocalidad:\nUsaquén\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE CODABAS",
#     "direccion": "CALLE 181A ENTRE CARRERA 7C Y 8 COSTADO SUR-. ORIENTAL.",
#     "horario": "7:00:00 a. m.",
#     "dias": "MIÉRCOLES - VIERNES",
#     "localidad": "Usaquén",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nLA PAZ CARACAS SECTOR NARANJOS DANUBIO AZUL\nDirección:\nDIAGONAL 53 D SUR TRANSVELSAL  3 A ESTE\nHorario:\n8:00:00 a. m.\nDías:\nMARTES - VIERNES\nLocalidad:\nRafael Uribe Uribe\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "LA PAZ CARACAS SECTOR NARANJOS DANUBIO AZUL",
#     "direccion": "DIAGONAL 53 D SUR TRANSVELSAL  3 A ESTE",
#     "horario": "8:00:00 a. m.",
#     "dias": "MARTES - VIERNES",
#     "localidad": "Rafael Uribe Uribe",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE RAFAEL NÚÑEZ\nDirección:\nCALLE 47 CON CARRERA 50\nHorario:\n7:30:00 a. m.\nDías:\nMIÉRCOLES - VIERNES\nLocalidad:\nTeusaquillo\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE RAFAEL NÚÑEZ",
#     "direccion": "CALLE 47 CON CARRERA 50",
#     "horario": "7:30:00 a. m.",
#     "dias": "MIÉRCOLES - VIERNES",
#     "localidad": "Teusaquillo",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE LA AURORA II\nDirección:\nDIAGONAL 69 F SUR # 14U- 45\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES\nLocalidad:\nUsme\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE LA AURORA II",
#     "direccion": "DIAGONAL 69 F SUR # 14U- 45",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES",
#     "localidad": "Usme",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE CAYETANO\nDirección:\nCARRERA 80 # 40 - 55 sur\nHorario:\n8:00:00 a. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE CAYETANO",
#     "direccion": "CARRERA 80 # 40 - 55 sur",
#     "horario": "8:00:00 a. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE NUEVA ROMA\nDirección:\nCALLE 57A SUR #77K-66\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - MIÉRCOLES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE NUEVA ROMA",
#     "direccion": "CALLE 57A SUR #77K-66",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - MIÉRCOLES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPOLIDEPORTIVO DE TIBABUYES\nDirección:\nCLL 139 # 127 C 48\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - MIÉRCOLES\nLocalidad:\nSuba\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "POLIDEPORTIVO DE TIBABUYES",
#     "direccion": "CLL 139 # 127 C 48",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - MIÉRCOLES",
#     "localidad": "Suba",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nURBANIZACIÓN VICTORIA NORTE\nDirección:\nCALLE 150 N 53 91\nHorario:\n7:00:00 a. m.\nDías:\nVIERNES\nLocalidad:\nSuba\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "URBANIZACIÓN VICTORIA NORTE",
#     "direccion": "CALLE 150 N 53 91",
#     "horario": "7:00:00 a. m.",
#     "dias": "VIERNES",
#     "localidad": "Suba",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nSOLAR I\nDirección:\nNOMENCLATURA OFICIAL KR 109B 141A 26\nHorario:\n8:00:00 a. m.\nDías:\nLUNES\nLocalidad:\nSuba\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "SOLAR I",
#     "direccion": "NOMENCLATURA OFICIAL KR 109B 141A 26",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES",
#     "localidad": "Suba",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nURB. SAN PEDRO DE USME PARQUE 1\nDirección:\nCALLE 65 SUR CON CARRERA 1 C ESTE\nHorario:\n7:30:00 a. m.\nDías:\nMIÉRCOLES - VIERNES\nLocalidad:\nUsme\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "URB. SAN PEDRO DE USME PARQUE 1",
#     "direccion": "CALLE 65 SUR CON CARRERA 1 C ESTE",
#     "horario": "7:30:00 a. m.",
#     "dias": "MIÉRCOLES - VIERNES",
#     "localidad": "Usme",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCENTRO DESARROLLO COMUNITARIO EL PORVENIR (MANZANA PORVENIR)\nDirección:\nCARRERA 100 # 52 - 24\nHorario:\n9:00:00 a. m.\nDías:\nLUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES\nLocalidad:\nBosa\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CENTRO DESARROLLO COMUNITARIO EL PORVENIR (MANZANA PORVENIR)",
#     "direccion": "CARRERA 100 # 52 - 24",
#     "horario": "9:00:00 a. m.",
#     "dias": "LUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES",
#     "localidad": "Bosa",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE BABILONIA\nDirección:\nAv. 9 No. 164 -13\nHorario:\n2:00:00 p. m.\nDías:\nMARTES\nLocalidad:\nUsaquén\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE BABILONIA",
#     "direccion": "Av. 9 No. 164 -13",
#     "horario": "2:00:00 p. m.",
#     "dias": "MARTES",
#     "localidad": "Usaquén",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE MARSELLA\nDirección:\nTRANSVERSAL 70 N° 9A-73\nHorario:\n7:30:00 a. m.\nDías:\nMIÉRCOLES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE MARSELLA",
#     "direccion": "TRANSVERSAL 70 N° 9A-73",
#     "horario": "7:30:00 a. m.",
#     "dias": "MIÉRCOLES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE URB. SAN DIEGO (CAI MAZUREN)\nDirección:\nCLL 164 # 52\nHorario:\n8:00:00 a. m.\nDías:\nLUNES - VIERNES\nLocalidad:\nSuba\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE URB. SAN DIEGO (CAI MAZUREN)",
#     "direccion": "CLL 164 # 52",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES - VIERNES",
#     "localidad": "Suba",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCENTRO DESARROLLO COMUNITARIO SAMORE\nDirección:\nCL 41A SUR NO. 31 46\nHorario:\n2:00:00 p. m.\nDías:\nMIÉRCOLES\nLocalidad:\nRafael Uribe Uribe\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CENTRO DESARROLLO COMUNITARIO SAMORE",
#     "direccion": "CL 41A SUR NO. 31 46",
#     "horario": "2:00:00 p. m.",
#     "dias": "MIÉRCOLES",
#     "localidad": "Rafael Uribe Uribe",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nCANAL DEL RIO NEGRO\nDirección:\nCALLE 94 #59-17\nHorario:\n8:30:00 a. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nAntonio Nariño\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "CANAL DEL RIO NEGRO",
#     "direccion": "CALLE 94 #59-17",
#     "horario": "8:30:00 a. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Antonio Nariño",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE VILLAS DEL DORADO-JABOQUE\nDirección:\nCARRERA 127 Con Calle 66c Costado Sur-oriental\nHorario:\n8:00:00 a. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nEngativá\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE VILLAS DEL DORADO-JABOQUE",
#     "direccion": "CARRERA 127 Con Calle 66c Costado Sur-oriental",
#     "horario": "8:00:00 a. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Engativá",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE TAKAY \"GRAN AMÉRICA\"\nDirección:\nCALLE. 25 #32A 90\nHorario:\n7:00:00 a. m.\nDías:\nLUNES - JUEVES\nLocalidad:\nTeusaquillo\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE TAKAY \"GRAN AMÉRICA\"",
#     "direccion": "CALLE. 25 #32A 90",
#     "horario": "7:00:00 a. m.",
#     "dias": "LUNES - JUEVES",
#     "localidad": "Teusaquillo",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE PARIS GAITÁN\nDirección:\nDIAGONAL 87 Bis 79A 47\nHorario:\n9:00:00 a. m.\nDías:\nMARTES - VIERNES\nLocalidad:\nEngativá\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE PARIS GAITÁN",
#     "direccion": "DIAGONAL 87 Bis 79A 47",
#     "horario": "9:00:00 a. m.",
#     "dias": "MARTES - VIERNES",
#     "localidad": "Engativá",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE TISQUESUSA\nDirección:\nDiagonal 81i Con Transversal 76 Costado Nor-occide\nHorario:\n7:00:00 a. m.\nDías:\nMIÉRCOLES - VIERNES\nLocalidad:\nEngativá\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE TISQUESUSA",
#     "direccion": "Diagonal 81i Con Transversal 76 Costado Nor-occide",
#     "horario": "7:00:00 a. m.",
#     "dias": "MIÉRCOLES - VIERNES",
#     "localidad": "Engativá",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCDC BELLAVISTA (MANZANA BELLAVISTA)\nDirección:\nCALLE 38 SUR # 94 C - 29\nHorario:\n2:00:00 p. m.\nDías:\nLUNES - VIERNES\nLocalidad:\nKennedy\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CDC BELLAVISTA (MANZANA BELLAVISTA)",
#     "direccion": "CALLE 38 SUR # 94 C - 29",
#     "horario": "2:00:00 p. m.",
#     "dias": "LUNES - VIERNES",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Caminatas\nEscenario:\nHumedal El Burro\nDirección:\nAvenida Ciudad de Cali No. 6C-09 (frente a la Biblioteca El Tintal, sector\nHorario:\n08:00 a.m.  a 11:00 a.m.\nDías:\nDomingo 12 de octubre\nLocalidad:\nKennedy\nFecha comienzo:\n12 de Octubre 2025\nFecha finalizacion:\n12 de Octubre 2025\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Caminatas",
#     "escenario": "Humedal El Burro",
#     "direccion": "Avenida Ciudad de Cali No. 6C-09 (frente a la Biblioteca El Tintal, sector",
#     "horario": "08:00 a.m.  a 11:00 a.m.",
#     "dias": "Domingo 12 de octubre",
#     "localidad": "Kennedy",
#     "mas_info_url": "https://portalciudadano.idrd.gov.co/parques/actividades/deportes/10049-caminatas-recreativas"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE NARANJOS\nDirección:\nCL70 BIS SUR N°80K-2\nHorario:\n7:00:00 a. m.\nDías:\nMIÉRCOLES - JUEVES\nLocalidad:\nBosa\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE NARANJOS",
#     "direccion": "CL70 BIS SUR N°80K-2",
#     "horario": "7:00:00 a. m.",
#     "dias": "MIÉRCOLES - JUEVES",
#     "localidad": "Bosa",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Manzanas del cuidado\nEscenario:\nCIOM SAN BLAS (MANZANA CEFE SAN CRISTOBAL)\nDirección:\nCRA 8 # 15 72 SUR\nHorario:\n2:00:00 p. m.\nDías:\nMARTES - MIÉRCOLES - JUEVES\nLocalidad:\nSan Cristóbal\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Manzanas del cuidado",
#     "escenario": "CIOM SAN BLAS (MANZANA CEFE SAN CRISTOBAL)",
#     "direccion": "CRA 8 # 15 72 SUR",
#     "horario": "2:00:00 p. m.",
#     "dias": "MARTES - MIÉRCOLES - JUEVES",
#     "localidad": "San Cristóbal",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/manzanas-del-cuidado "
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nPARQUE QUIRINAL\nDirección:\nCALLE 59 # 56-53\nHorario:\n6:30:00 a. m.\nDías:\nMARTES - JUEVES\nLocalidad:\nTeusaquillo\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "PARQUE QUIRINAL",
#     "direccion": "CALLE 59 # 56-53",
#     "horario": "6:30:00 a. m.",
#     "dias": "MARTES - JUEVES",
#     "localidad": "Teusaquillo",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   },
#   {
#     "raw_text": "Persona Mayor\nEscenario:\nDESARROLLO EL PORTAL DE LAS MERCEDES\nDirección:\nENTRE CARRERAS 109B Y 110 CON CALLE 152D Y ESTACIONAMIENTOS DE LA CALLE 152C\nHorario:\n8:00:00 a. m.\nDías:\nLUNES\nLocalidad:\nSuba\n* Fechas y horarios sujetos a cambios sin previo aviso",
#     "titulo": "Persona Mayor",
#     "escenario": "DESARROLLO EL PORTAL DE LAS MERCEDES",
#     "direccion": "ENTRE CARRERAS 109B Y 110 CON CALLE 152D Y ESTACIONAMIENTOS DE LA CALLE 152C",
#     "horario": "8:00:00 a. m.",
#     "dias": "LUNES",
#     "localidad": "Suba",
#     "mas_info_url": "https://www.idrd.gov.co/recreacion/actividad-fisica-y-deporte/persona-mayor"
#   }
# ]

# %%
df = pd.DataFrame(result)

# Guardar en CSV
df.to_csv("programas_idrd.csv", index=False, encoding="utf-8-sig")

print("Archivo CSV guardado como 'programas_idrd.csv'")
# Out:
# Archivo CSV guardado como 'programas_idrd.csv'
