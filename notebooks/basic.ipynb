# %%
import requests
from bs4 import BeautifulSoup
import re
from urllib.parse import urljoin
import json
import pandas as pd

# %%
BASE_URL = "https://www.idrd.gov.co"
START_URL = "https://www.idrd.gov.co/nuestros-programas"

headers = {
    "User-Agent": "Mozilla/5.0 (compatible; DataCollector/1.0; +https://yourdomain.example)"
}

resp = requests.get(START_URL, headers=headers, timeout=15)
resp.raise_for_status()
soup = BeautifulSoup(resp.text, "html.parser")

LOCALIDADES_VALIDAS = [
    "chapinero", "suba", "usaquén", "candelaria", "teusaquillo", "fontibón", "engativá", "barrios unidos",
    "bosa", "kennedy", "tunjuelito", "puente aranda", "martires", "santa fe", "antonio nariño", "san cristóbal",
    "laureles", "unificada"
]

cards = []
for marker in soup.find_all(string=re.compile(r'Escenario:', re.IGNORECASE)):
    container = marker.find_parent()
    for _ in range(4):
        text = container.get_text(separator="\n", strip=True)
        if re.search(r'Horario[:\s]', text) and re.search(r'Direcci[oó]n[:\s]', text):
            break
        if container.parent:
            container = container.parent
    text = container.get_text(separator="\n", strip=True)
    lines = [l.strip() for l in text.splitlines() if l.strip()]

    # Nombre/título heurística (primera línea significativa)
    nombre = None
    for line in lines:
        if not re.search(r'Escenario:|Direcci[oó]n:|Horario:|D[ií]as:|Localidad:|Tel[eé]fono:|Email:|Web:|Gratuita:', line, re.IGNORECASE):
            nombre = line
            break

    def extract(pattern, text):
        m = re.search(pattern, text, re.IGNORECASE)
        return m.group(1).strip() if m else None

    # Dirección
    direccion = extract(r'Direcci[oó]n[:\s]*([^\n\r]+)', text)

    # es_gratuita SIEMPRE TRUE
    es_gratuita = True

    # Días de la actividad
    dias = extract(r'D[ií]as[:\s]*([^\n\r]+)', text)

    # Contacto FIJO
    contacto = "+57 (601) 6605400 Ext.251 y 252"

    # Escenario: extrae el escenario donde se realiza la actividad (según patrón)
    escenario = extract(r'Escenario[:\s]*([^\n\r]+)', text)

    # Localidad: realiza el matching flexible, si no coincide deja el texto original
    localidad_line = extract(r'Localidad[:\s]*([^\n\r]+)', text)
    localidad = None
    if localidad_line:
        loc_clean = localidad_line.strip().lower()
        for loc_option in LOCALIDADES_VALIDAS:
            if loc_option in loc_clean:
                localidad = loc_option
                break
        if not localidad:
            localidad = loc_clean  # Si no está en lista, lo deja igual

    # Produce solo si nombre y dirección están presentes
    if nombre and direccion:
        datos = {
            'nombre': nombre,
            'direccion': direccion,
            'es_gratuita': es_gratuita,
            'dias': dias,
            'contacto': contacto,
            'escenario': escenario,
            'localidad': localidad
        }
        cards.append(datos)

# Deduplicar por (nombre, direccion)
unique = {}
for c in cards:
    key = (c.get('nombre'), c.get('direccion'))
    unique[key] = c
result = list(unique.values())

print(json.dumps(result, ensure_ascii=False, indent=2))

if result:
    df = pd.DataFrame(result)
    df.to_csv("programas_idrd_transformado.csv", index=False, encoding="utf-8-sig")
    print("Archivo CSV guardado como 'programas_idrd_transformado.csv'")
else:
    print("No se encontraron datos útiles para guardar.")
# Out:
# [
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 1A ESTE # 7-34",
#     "es_gratuita": true,
#     "dias": "MARTES - MIÉRCOLES - JUEVES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "POLIDEPORTIVO PARQUE BARRIO EGIPTO (4625)",
#     "localidad": "candelaria"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "ESQUINA SUR OCCIDENTAL DE LA CALLE 159 A BIS CON CARRERA 90",
#     "es_gratuita": true,
#     "dias": "MARTES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "AGRUPACIÓN DE VIVIENDA LAS MERCEDES (SALITRE)",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 181A ENTRE CARRERA 7C Y 8 COSTADO SUR-. ORIENTAL.",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE CODABAS",
#     "localidad": "usaquén"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "AVENIDA CARRERA. 60 # 57 - 60",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE  VIRGILIO BARCO",
#     "localidad": "teusaquillo"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 17A SUR 2A -60 ESTE",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CEFE SAN CRISTOBAL (MANZANA CEFE SAN CRISTOBAL)",
#     "localidad": "san cristóbal"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 55 A SUR # 65 03",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE VILLA DEL RIO",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 70ª BIS # 77L-06",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SALÓN COMUNAL NUEVA GRANADA 1 SECTOR (MANZANA PORVENIR)",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "TRANSVERSAL 1 ESTE 24 A 13 SUR",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE MONTEBELLO",
#     "localidad": "san cristóbal"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "AVENIDA CALLE 3 CON TRANSVERSAL 49 COSTADO NOROCCIDENTAL",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE CAMELIA NORTE",
#     "localidad": "puente aranda"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 71 #81 a 70",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "BOYACÁ REAL ( MANZANA DEL CUIDADO ENGATIVÁ)",
#     "localidad": "engativá"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 100 # 52 - 24",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CENTRO DESARROLLO COMUNITARIO EL PORVENIR (MANZANA PORVENIR)",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 94 #59-17",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CANAL DEL RIO NEGRO",
#     "localidad": "antonio nariño"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 1C ESTE CON CALLE 94A SUR COSTADO SUR",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE EL VIRREY( MANZANAS DEL CUIDADO USME )",
#     "localidad": "usme"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 185b # 3A-26",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "S.C. BELLO HORIZONTE (MANZANA USAQUÉN)",
#     "localidad": "usaquén"
#   },
#   {
#     "nombre": "Caminatas",
#     "direccion": "Avenida Jiménez entre carreras 6A y 7A, frente al Café Pasaje de la Plazoleta del Rosario (Carrera 12 No. 7-74).",
#     "es_gratuita": true,
#     "dias": "Domingo 2 de noviembre",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "Eje Ambiental - Río San Francisco Vicachá",
#     "localidad": "santa fe"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CRA 105 B # 132 B",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE ALCAPARROS DE SUBA",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 34 BIS SUR N°  95a-56",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - MIÉRCOLES-VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE TIERRA BUENA",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 144C #141C",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CEFE FONTANAR DEL RIO",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "AVENIDA CALLE 54 S # 97-37",
#     "es_gratuita": true,
#     "dias": "MARTES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE PORVENIR (MANZANA  PORVENIR)",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 68 C N° 2-04 Sur",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LA FLORESTA",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 161 CON CRA 13 B",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE BALCONES DE ORIENTE",
#     "localidad": "usaquén"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 56 sur # 81- 47",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SALÓN COMUNAL  CARIMAGUA (MANZANA TIMIZA)",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Caminatas",
#     "direccion": "Parque Bosque de San Carlos - Mirador La Resurrección",
#     "es_gratuita": true,
#     "dias": "Domingo 16 de noviembre",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "Parque Bosque de San Carlos - Mirador La Resurrección  (18-028)",
#     "localidad": "rafael uribe uribe"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 48 P BIS C SUR N 4-30",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "POLIDEPORTIVO LOS MOLINOS II",
#     "localidad": "rafael uribe uribe"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CL 188 B 11 46",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE EL OTOÑO",
#     "localidad": "usaquén"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 99A CON CALLE 54 SUR",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE ATALAYAS II SECTOR",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "AVENIDA GUAYACANES CALLE 49 SUR",
#     "es_gratuita": true,
#     "dias": "MARTES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LAS MARGARITAS",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "ENTRE CALLE 50 Y CALLE 51 CON CARRERA 21 Y CARRERA 22",
#     "es_gratuita": true,
#     "dias": "JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE ALFONSO LÓPEZ",
#     "localidad": "teusaquillo"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "DIAGONAL 60B SUR 14H ESTE 02",
#     "es_gratuita": true,
#     "dias": "JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE NUEVA DELHI",
#     "localidad": "san cristóbal"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 91 A SUR 3 C - 34",
#     "es_gratuita": true,
#     "dias": "LUNES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CENTRO DE DESARROLLO COMUNITARIO  JULIO CESAR SÁNCHEZ(MANZANAS DEL CUIDADO USME)",
#     "localidad": "usme"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 12 B BIS A # 0-08",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LA CONCORDIA - (MANZANA CENTRO)",
#     "localidad": "candelaria"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "DIAGONAL 87 Bis 79A 47",
#     "es_gratuita": true,
#     "dias": "MARTES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE PARIS GAITÁN",
#     "localidad": "engativá"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 69 K BIS SUR #35-1",
#     "es_gratuita": true,
#     "dias": "LUNES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CENTRO DIA TEJEDORES",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CRA. 80I #73C SUR-2 A 73C SUR-52",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE ALAMEDA",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CL 76 55A 75",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE JORGE ELIECER GAITÁN",
#     "localidad": "antonio nariño"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 71 # 10-47",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CASA DE LA SABIDURÍA  (MANZANA CHAPINERO )",
#     "localidad": "chapinero"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "Entre Carrera 92 Y Carrera 93 A Con Calle 76 Bis",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE SANTA ROSITA",
#     "localidad": "engativá"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 59 A SUR N 8600",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "POLIDEPORTIVO LA ESTANCIA",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 152 CON  CARRERA 7C",
#     "es_gratuita": true,
#     "dias": "JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE SONORA",
#     "localidad": "usaquén"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 89 F #42 20 SUR",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "LAS BRISAS",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CL 53 SUR CRA 11 A",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SALÓN COMUNAL ABRAHÁN LINCOLN(MANZANAS DEL CUIDADO)",
#     "localidad": "tunjuelito"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 72A BIS SUR #13-21 ESTE",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "AULA AMBIENTAL JUAN REY (MANZANA JUAN REY)",
#     "localidad": "san cristóbal"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 25 # 69 - 94",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE CIUDAD SALITRE",
#     "localidad": "teusaquillo"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CLL 141 # 99 B 02",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE EL PÓRTICO",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 22 F # 86-99",
#     "es_gratuita": true,
#     "dias": "MARTES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "FUENTE DEL DORADO ETAPA II",
#     "localidad": "fontibón"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE61SUR#66A-2",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CANCHA COMUNAL MADELENA",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 104 # 71 C- 23",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE EL CARMELO",
#     "localidad": "engativá"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE. 4a Bis #18B-30",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE EDUARDO SANTOS",
#     "localidad": "los mártires"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE14B#119A-17",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "RECODO HYNTIBA SALÓN DEPORTIVO",
#     "localidad": "fontibón"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "DIAGONAL 32 Sur # 3 - 41",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE VILLA MAYOR",
#     "localidad": "antonio nariño"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "AVENIDA 1 Nº 22 A O6",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CENTRO DIA MONTAÑA DEL SABER",
#     "localidad": "san cristóbal"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 52 BIS #19-53, Bogotá",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE TORREMOLINOS I SECTOR",
#     "localidad": "puente aranda"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 19D # 52B - 15",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "URBANIZACIÓN EL TUNALII-MINITUNAL",
#     "localidad": "tunjuelito"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 68# 58-13",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CENTRO DE DESARROLLO COMUNITARIO MARÍA GORRETI",
#     "localidad": "antonio nariño"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 7A # 182-35",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CENTRO DIA USAQUEN CASA DEL ÁRBOL  (MANZANA USAQUÉN)",
#     "localidad": "usaquén"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 74 # 42 G - 52 SUR",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CDC LAGO TIMIZA (MANZANA TIMIZA)",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "TRANSVERSAL88a 81-0",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LA ESPAÑOLITA",
#     "localidad": "engativá"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 102 CON CALLE 69 A SUR",
#     "es_gratuita": true,
#     "dias": "MARTES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE RECREO",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 39B # 19-46",
#     "es_gratuita": true,
#     "dias": "LUNES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CASA DE LA PARTICIPACIÓN",
#     "localidad": "teusaquillo"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 22 Sur #3-10, Bogotá",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SALÓN COMUNAL POLICARPA",
#     "localidad": "antonio nariño"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "DIAGONAL 16 F BIS # 104 A -15",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE CARMEN DE LA LAGUNA",
#     "localidad": "fontibón"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 9 SUR CON CARRERA 25 COSTADO NORORIENTAL",
#     "es_gratuita": true,
#     "dias": "LUNES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE URBANIZACIÓN LA FRAGUITA",
#     "localidad": "antonio nariño"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 29 SUR # 37 - 21",
#     "es_gratuita": true,
#     "dias": "MARTES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LOS SAUCES",
#     "localidad": "puente aranda"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CRA 4A 186-26",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "DESARROLLO CHAPARRAL",
#     "localidad": "usaquén"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 69 47 43",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "INTEGRACIÓN SOCIAL EL CAMINO( MANZANA ENGATIVÁ)",
#     "localidad": "engativá"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 47 SUR  N° 72 I -06",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE TUNDAMA",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 78D BIS A 41 G - 15",
#     "es_gratuita": true,
#     "dias": "MARTES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SALÓN COMUNAL PALENQUE",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CRA 151 CALLE 132",
#     "es_gratuita": true,
#     "dias": "LUNES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SANTA RITA(BOTA)",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 52 A SUR # 77 W-05",
#     "es_gratuita": true,
#     "dias": "LUNES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CATALINA 1",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 57 # 56 - 36",
#     "es_gratuita": true,
#     "dias": "JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE PABLO VI",
#     "localidad": "teusaquillo"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 136A #151F-01",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE BOSQUE ENCANTADO",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA100#24D-65",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SALÓN COMUNAL SAN JOSÉ",
#     "localidad": "fontibón"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 65 SUR CON CARRERA 1 C ESTE",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "URB. SAN PEDRO DE USME PARQUE 1",
#     "localidad": "usme"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 39B CON CALLE 37A",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LA VIRGEN",
#     "localidad": "puente aranda"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 100 # 52 - 25",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - MIÉRCOLES - JUEVES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CENTRO DESARROLLO COMUNITARIO EL PORVENIR (MANZANA PORVENIR)",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "DIAGONAL 46 # 16 - 25",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE GUERNIKA",
#     "localidad": "teusaquillo"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 191 CON CRA 8",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE TIBABITA",
#     "localidad": "usaquén"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 67 #25-65",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE JJ. VARGAS",
#     "localidad": "antonio nariño"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "DIAGONAL  41 SUR # 34a - 90",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SALÓN COMUNAL NUEVA VILLA MAYOR (MANZANA SAMORE)",
#     "localidad": "rafael uribe uribe"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CL 181 BIS 10 A 00",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "VILLAS DE ANDALUCÍA",
#     "localidad": "usaquén"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "TRANS 126 # 134 - 88",
#     "es_gratuita": true,
#     "dias": "MARTES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CADE GAITANA",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 93 SUR # 6B -12 ESTE",
#     "es_gratuita": true,
#     "dias": "MARTES - MIÉRCOLES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "DESARROLLO ALFONSO LÓPEZ  SECTOR NUEVO PROGRESO",
#     "localidad": "usme"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 1A 68C, C 68C SUR",
#     "es_gratuita": true,
#     "dias": "MARTES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CANDELARIA SALÓN COMUNAL (MANZANA SIERRA MORENA)",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 146 C BIS # 90 - 57",
#     "es_gratuita": true,
#     "dias": "MARTES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE BERLÍN",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 1A # 1 - 41",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CENTRO PASTORAL SAN JUAN DE DIOS (5095)",
#     "localidad": "santa fe"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 29 ENTRE CALLE 3A Y CALLE 3 COSTADO NOROCCIDENTAL",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE SANTA ISABEL",
#     "localidad": "los mártires"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 110 #76-18",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "URBANIZACIÓN GARCES NAVAS (CASA ADULTO MAYOR)",
#     "localidad": "engativá"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 81 F # 11B 10",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SANTA CATALINA",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "TV 1C BIS ENTRE CALLE 76 SUR Y CALLE 76B SUR",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LA MARICHUELA",
#     "localidad": "usme"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CRA 18 L # 70B - 50 SUR",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SUPER CADE MANITAS (MANZANA MANITAS)",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 100 #52- SUR 24S",
#     "es_gratuita": true,
#     "dias": "MARTES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CABILDO INDÍGENA",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 40 H SUR N 70A 81",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE CARMELO III",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 69 47 44",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "INTEGRACIÓN SOCIAL EL CAMINO( MANZANA ENGATIVÁ)",
#     "localidad": "engativá"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 166 # 8D-44",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "VILLAS DE ARANJUEZ PRIMERA ETAPA",
#     "localidad": "usaquén"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 13C CON CARRERA 123",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE EL DORMILÓN",
#     "localidad": "fontibón"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 152 CARRERA 24 A COSTADO ORIENTAL",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "URBANIZACIÓN EL CEDRAL",
#     "localidad": "usaquén"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 53A SUR # 72",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE URBANIZACIÓN OLARTE",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 9A CON CALLE 35 BIS COSTADO NORTE",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "POLIDEPORTIVO MANAGUA BARCELONA",
#     "localidad": "san cristóbal"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 167 A #5A - 4",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LA CITA (MANZANA USAQUÉN)",
#     "localidad": "usaquén"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 63 # 59A - 06",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE VILLAS DE GRANADA",
#     "localidad": "engativá"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 56D SUR ENTRE 72D Y CARRERA 72F",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE DESARROLLO  NUEVO CHILE",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "ZONA UBICADA EN LA PROLONGACIÓN DE LA CALLE 14 SUR ENTRE CARRERA 4 Y CARRERA 6",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE VELÓDROMO ( MANZANAS DEL CUIDADO CEFE SAN CRISTOBAL)",
#     "localidad": "san cristóbal"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CL 41A SUR NO. 31 46",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CENTRO DESARROLLO COMUNITARIO SAMORE",
#     "localidad": "rafael uribe uribe"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 91 C SUR # 18H - 14",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "MOCHUELO (MANZANA MOCHUELO)",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA77#21-05",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LA FELICIDAD",
#     "localidad": "fontibón"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CL 57 SUR#18 A-23",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "DESARROLLO SAN BENITO",
#     "localidad": "tunjuelito"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 43 #5, Bogotá",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE CHAMPIONS",
#     "localidad": "puente aranda"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CRA 19B N 62B 05",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CANCHA COMUNAL ACACIAS",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 2 #87-15",
#     "es_gratuita": true,
#     "dias": "MARTES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE PATIO BONITO 2 SECTOR",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CL 189 C 3 A 01",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "BUENAVISTA SEGUNDO SECTOR",
#     "localidad": "usaquén"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 17B #13-16",
#     "es_gratuita": true,
#     "dias": "LUNES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE VILLA DIANA",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "DIAGONAL 53 D SUR TRANSVELSAL  3 A ESTE",
#     "es_gratuita": true,
#     "dias": "MARTES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "LA PAZ CARACAS SECTOR NARANJOS DANUBIO AZUL",
#     "localidad": "rafael uribe uribe"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CRA.50 # 22-41",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LOS CIPRÉS",
#     "localidad": "teusaquillo"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "TV. 2A #135  SUR-67 A 135 SUR- 99",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PUEBLO USME",
#     "localidad": "usme"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "DIAGONAL 73C # 57 - 17",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "ECOPARQUE SIERRA MORENA (MANZANA SIERRA MORENA",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CON CARRERA 52C, CALLE 28 SUR, Puente Aranda, Bogotá",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE EL TEJAR",
#     "localidad": "puente aranda"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 1 B # 57 - 51",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CENTRO DE DESARROLLO COMUNITARIO JOSÉ ANTONIO GALÁN",
#     "localidad": "puente aranda"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 47 / CALLE 56B 47",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LOS CONQUISTADORES",
#     "localidad": "teusaquillo"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "ENTRE CALLE 31C SUR Y CALLE 32C SUR CON CARRERA 3 ESTE",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE BELLO HORIZONTE",
#     "localidad": "san cristóbal"
#   },
#   {
#     "nombre": "Caminatas",
#     "direccion": "Carrera 3 con Calle 137C Sur",
#     "es_gratuita": true,
#     "dias": "Domingo 23 de noviembre",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "Usme - Pasquilla",
#     "localidad": "usme"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLES 71G SUR Y 71I SUR Y CARRERAS 27L Y 27J",
#     "es_gratuita": true,
#     "dias": "JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE DESARROLLO EL PARAÍSO",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "TRANSVERSAL 21 A #19 - 54 SUR",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "BIBLIOTECA CARLOS E. RESTREPO (MANZANA DE ANTONIO NARIÑO)",
#     "localidad": "antonio nariño"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "ENTRE CARRERAS 109B Y 110 CON CALLE 152D Y ESTACIONAMIENTOS DE LA CALLE 152C",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "DESARROLLO EL PORTAL DE LAS MERCEDES",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "ENTRE CALLE 50 Y CALLE 51 CON CARRERA 21 Y CARRERA 22",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE ALFONSO LÓPEZ",
#     "localidad": "teusaquillo"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "A26, Cl. 74 #77, Engativá, Bogotá",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "URBANIZACIÓN TABORA",
#     "localidad": "engativá"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CRA 92 C # 119",
#     "es_gratuita": true,
#     "dias": "LUNES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE SAN GABRIEL",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA  90 # 84 A 38",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "URBANIZACIÓN QUIRIGUA",
#     "localidad": "engativá"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 32 SUR 8 53",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SALÓN COMUNAL SAN ISIDRO 1 SECTOR",
#     "localidad": "san cristóbal"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CLL 139 # 127 C 48",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "POLIDEPORTIVO DE TIBABUYES",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CLL 127 C # 49 78",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE TIERRA LINDA",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 1 B # 52 A - 14",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - JUEVES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LA PONDEROSA",
#     "localidad": "puente aranda"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 51 C SUR # 82 A -09",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE VILLA ANDREA",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 66 SUR# 11A 62  ESTE",
#     "es_gratuita": true,
#     "dias": "LUNES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE VALPARAÍSO",
#     "localidad": "san cristóbal"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 11, Tv. 12, Bogotá",
#     "es_gratuita": true,
#     "dias": "SÁBADO",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE CIUDAD JARDÍN",
#     "localidad": "antonio nariño"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 51SUR CARRERA 37 SUR -98",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "URBANIZACIÓN JAL FÁTIMA",
#     "localidad": "tunjuelito"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "AVENIDA CARRERA 50 N 1 D 28",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE COLISEO EL JAZMÍN",
#     "localidad": "puente aranda"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE. 25 #32A 90",
#     "es_gratuita": true,
#     "dias": "LUNES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE TAKAY \"GRAN AMÉRICA\"",
#     "localidad": "teusaquillo"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CLL 137 # 102",
#     "es_gratuita": true,
#     "dias": "MARTES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE COSTA AZUL 1",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 141 # 111 - 32",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE COMUNEROS",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 93D # 59B",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE URBANIZACIÓN SANTIAGO DE ATALAYAS",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "TRANSVERSAL 70 N° 9A-73",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE MARSELLA",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 80 BIS SUR, 94-21",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SALÓN COMUNAL ALCAPARRO (MANZANA CAMPO VERDE)",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Caminatas",
#     "direccion": "Templete de Simón Bolívar",
#     "es_gratuita": true,
#     "dias": "Domingo 30 de noviembre",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "Parque de los Periodistas - Parque El Guavio",
#     "localidad": "candelaria"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 68D SUR #18- 38",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CANCHA COMUNAL MARANDU",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CRA 18 N # 64 A SUR 35",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CANCHA COMUNAL JOSÉ DOMINGOS Y FESTIVOS LAING",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 85 SUR #92-85",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE ZONAL CAMPO VERDE (MANZANA CAMPO VERDE)",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 6 #51 3A",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CDC LOURDES (MANZANA CENTRO)",
#     "localidad": "santa fe"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "TV 142 # 150 A 40",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CANCHA FONTANAR",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 81 BIS SUR # 8A- 24",
#     "es_gratuita": true,
#     "dias": "JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LA ANDREA",
#     "localidad": "usme"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 88 ENTRE CRA 7 Y AUT NORTE",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CANAL EL VIRREY- EL CHICO",
#     "localidad": "chapinero"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CRA 96 #161",
#     "es_gratuita": true,
#     "dias": "MARTES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE RESIDENCIAL EL SALITRE",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 80SUR#17-80",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SAN JOAQUÍN ARBUELOS",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 115 A # 18 A- 40",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE ATAHUALPA",
#     "localidad": "fontibón"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 68 SUR NUMERO 81 C 09",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE PALESTINA",
#     "localidad": "bosa"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 81 B # 19 - 00",
#     "es_gratuita": true,
#     "dias": "LUNES - MARTES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE BOSQUE DE HAYUELOS",
#     "localidad": "fontibón"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "DG 49 SUR 53 02",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "URBANIZACIÓN JAL VENECIA",
#     "localidad": "tunjuelito"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 12 # 7-44 sur",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE CIUDAD BERNA",
#     "localidad": "antonio nariño"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "DIAG 68A SUR No 17B - 11",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE ALAMEDA",
#     "localidad": "ciudad bolívar"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 35 A Sur #92B-21",
#     "es_gratuita": true,
#     "dias": "LUNES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "RIVERAS DE OCCIDENTE",
#     "localidad": "kennedy"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 102 # 129 - 78",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE LAGOS DE SUBA",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 60 # 18-41",
#     "es_gratuita": true,
#     "dias": "LUNES - MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE SAN LUIS",
#     "localidad": "antonio nariño"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 3 B N 35 04 SUR",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE VILLA DE LOS ALPES",
#     "localidad": "san cristóbal"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 135 # 54 D",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "URB NUEVO HORIZONTE (SAN JOSÉ DEL PRADO)",
#     "localidad": "suba"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 46 BIS SUR CON DIAGONAL 45 BIS CALLE 46A SUR  COSTADO NORTE",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE VILLA DEL CERRO",
#     "localidad": "san cristóbal"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "Diagonal 81i Con Transversal 76 Costado Nor-occide",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES - VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE TISQUESUSA",
#     "localidad": "engativá"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CARRERA 104 B # 22 J - 15",
#     "es_gratuita": true,
#     "dias": "VIERNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CDC LA GIRALDA MANZANAS DEL CUIDADO PUNTO",
#     "localidad": "fontibón"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CALLE 22 F # 86-99",
#     "es_gratuita": true,
#     "dias": "MARTES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "FUENTE DEL DORADO ETAPA II",
#     "localidad": "fontibón"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "CARRERA 4D BIS NUMERO 52 SUR 95",
#     "es_gratuita": true,
#     "dias": "LUNES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SALÓN COMUNAL LA PAZ SUR CEBADAL",
#     "localidad": "rafael uribe uribe"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "DIAGONAL  41 SUR # 34a - 91",
#     "es_gratuita": true,
#     "dias": "MARTES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SALÓN COMUNAL NUEVA VILLA MAYOR (MANZANA SAMORE)",
#     "localidad": "rafael uribe uribe"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CALLE 27 B SUR # 37 - 07",
#     "es_gratuita": true,
#     "dias": "LUNES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "CENTRO DIA MONSEÑOR - SANTA MATILDE",
#     "localidad": "puente aranda"
#   },
#   {
#     "nombre": "Manzanas del cuidado",
#     "direccion": "TRANSVERSAL 5F 48 P-10 SUR",
#     "es_gratuita": true,
#     "dias": "MARTES - MIÉRCOLES - JUEVES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "SALÓN COMUNAL BOSQUES DE IBARI",
#     "localidad": "rafael uribe uribe"
#   },
#   {
#     "nombre": "Persona Mayor",
#     "direccion": "CL. 71A SUR #81 44",
#     "es_gratuita": true,
#     "dias": "MIÉRCOLES",
#     "contacto": "+57 (601) 6605400 Ext.251 y 252",
#     "escenario": "PARQUE HUMBERTO VALENCIA",
#     "localidad": "bosa"
#   }
# ]
# Archivo CSV guardado como 'programas_idrd_transformado.csv'

# %%
df = pd.DataFrame(result)

# Guardar en CSV
df.to_csv("programas_idrd.csv", index=False, encoding="utf-8-sig")

print("Archivo CSV guardado como 'programas_idrd.csv'")
# Out:
# Archivo CSV guardado como 'programas_idrd.csv'
